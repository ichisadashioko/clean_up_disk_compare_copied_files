# %%
import os
import io
import hashlib
import math
import stat
import traceback

from tqdm import tqdm

# %%
def compute_filehash(
    fpath,
    filesize=None,
    chunksize=16777216,
):
    md5_obj = hashlib.md5()

    # if file size is 0
    if filesize is None:
        filesize = os.path.getsize(fpath)

    number_of_chunks = int(math.ceil(filesize / chunksize))
    if os.path.getsize(fpath) != 0:
        with open(fpath, mode='rb') as infile:
            pbar = tqdm(range(number_of_chunks))
            for i in pbar:
                pbar.set_description(f'{i}/{number_of_chunks} {fpath}')
                chunk = infile.read(chunksize)
                md5_obj.update(chunk)

    return md5_obj.hexdigest()


def get_file_info(fpath):
    # TODO
    # file info
    # - file size
    # - file hash
    # - modified date
    filename = os.path.basename(fpath)

    try:
        filestat = os.stat(fpath)

        if stat.S_ISREG(filestat.st_mode):
            # TODO
            filesize = filestat.st_size
            filehash = compute_filehash(fpath, filesize)

            return {
                'filename': filename,
                'filemode': filestat.st_mode,
                'filesize': filesize,
                'filehash': filehash,
                'modified': filestat.st_mtime,
            }
        elif stat.S_ISDIR(filestat.st_mode):
            # TODO
            filelist = []
            filename_list = os.listdir(fpath)
            for filename in filename_list:
                child_fpath = os.path.join(fpath, filename)
                filelist.append(get_file_info(child_fpath))
            return {
                'filename': filename,
                'filemode': filestat.st_mode,
                'filelist': filelist,
            }
        else:
            return {
                'filename': filename,
                'filemode': filestat.st_mode,
            }
    except Exception as ex:
        stack_trace_str = traceback.format_exc()
        return {
            'filename': filename,
            'stacktrace': stack_trace_str,
            'exception': ex,
        }

# %%
compute_filehash(r"D:\windows_iso\2020-02-13-raspbian-buster-lite.zip")
# Out:
# 27/28 D:\windows_iso\2020-02-13-raspbian-buster-lite.zip: 100%|████████████████████████| 28/28 [00:00<00:00, 39.70it/s]
# '2846dc28b392b8f9c65f7e78f2ae87d4'

# %%
root_node = get_file_info('D:/windows_iso/')
type(root_node)
# Out:
# 27/28 D:/windows_iso/2020-02-13-raspbian-buster-lite.zip: 100%|████████████████████████| 28/28 [00:00<00:00, 43.88it/s]
# 57/58 D:/windows_iso/android-x86_64-9.0-r2.iso: 100%|██████████████████████████████████| 58/58 [00:07<00:00,  7.63it/s]
# 197/198 D:/windows_iso/en_windows_7_professional_x64_dvd.iso: 100%|██████████████████| 198/198 [00:28<00:00,  6.85it/s]
# 36/37 D:/windows_iso/en_windows_xp_professional_with_service_pack_3_x86_cd_vl_x14-73974.iso: 100%|█| 37/37 [00:05<00:00
# 0/1 D:/windows_iso/rufus-3.13p\rufus-3.13p.exe: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 41.86it/s]
# 0/1 D:/windows_iso/rufus-3.13p\rufus.ini: 100%|█████████████████████████████████████████| 1/1 [00:00<00:00, 493.45it/s]
# 43/44 D:/windows_iso/ubuntu-10.04.4-desktop-amd64.iso: 100%|███████████████████████████| 44/44 [00:05<00:00,  7.69it/s]
# 114/115 D:/windows_iso/ubuntu-18.04-desktop-amd64.iso: 100%|█████████████████████████| 115/115 [00:14<00:00,  7.71it/s]
# 130/131 D:/windows_iso/ubuntu-18.04.5-desktop-amd64.iso: 100%|███████████████████████| 131/131 [00:19<00:00,  6.88it/s]
# 29/30 D:/windows_iso/ubuntu-18.04.5-preinstalled-server-armhf+raspi3.img.xz: 100%|█████| 30/30 [00:04<00:00,  6.96it/s]
# 165/166 D:/windows_iso/ubuntu-20.04.1-desktop-amd64.iso: 100%|███████████████████████| 166/166 [00:24<00:00,  6.82it/s]
# 40/41 D:/windows_iso/ubuntu-20.04.1-preinstalled-server-armhf+raspi.img.xz: 100%|██████| 41/41 [00:05<00:00,  6.98it/s]
# 171/172 D:/windows_iso/ubuntu-20.04.2.0-desktop-amd64.iso: 100%|█████████████████████| 172/172 [00:35<00:00,  4.81it/s]
# 347/348 D:/windows_iso/Win10_21H1_EnglishInternational_x64.iso: 100%|████████████████| 348/348 [00:52<00:00,  6.67it/s]
# 246/247 D:/windows_iso/Win10_21H1_English_x32.iso: 100%|█████████████████████████████| 247/247 [00:37<00:00,  6.66it/s]
# 347/348 D:/windows_iso/Win10_21H1_English_x64.iso: 100%|█████████████████████████████| 348/348 [00:52<00:00,  6.67it/s]
# 341/342 D:/windows_iso/Win10_21H1_Japanese_x64.iso: 100%|████████████████████████████| 342/342 [00:50<00:00,  6.72it/s]
# 351/352 D:/windows_iso/win7sp1_ldr_escrow_CLIENT_PROFESSIONAL_x64FRE_en-us.iso: 100%|█| 352/352 [00:52<00:00,  6.76it/s
# 292/293 D:/windows_iso/Windows-20210320.iso: 100%|███████████████████████████████████| 293/293 [00:37<00:00,  7.79it/s]
# 292/293 D:/windows_iso/Windows.iso: 100%|████████████████████████████████████████████| 293/293 [00:39<00:00,  7.38it/s]
# 29/30 D:/windows_iso/windows_xp_sp2_w2k3sp2_3959_usa_x64fre_spcd.iso: 100%|████████████| 30/30 [00:04<00:00,  7.00it/s]
# 36/37 D:/windows_iso/winxp_iso\en_windows_xp_professional_with_service_pack_3_x86_cd_vl_x14-73974.iso: 100%|█| 37/37 [0
# 39/40 D:/windows_iso/winxp_iso\ja_windows_xp_professional_with_service_pack_3_x86_dvd_vl_x14-74058.iso: 100%|█| 40/40 [
# 0/1 D:/windows_iso/winxp_iso\ja_windows_xp_professional_with_service_pack_3_x86_dvd_vl_x14-74058_key.txt: 100%|█| 1/1 [
# dict

# %%
root_node
# Out:
# {'filename': 'winxp_iso',
#  'filemode': 16895,
#  'filelist': [{'filename': '2020-02-13-raspbian-buster-lite.zip',
#    'filemode': 33206,
#    'filesize': 454047405,
#    'filehash': '2846dc28b392b8f9c65f7e78f2ae87d4',
#    'modified': 1586329362.829935},
#   {'filename': 'android-x86_64-9.0-r2.iso',
#    'filemode': 33206,
#    'filesize': 965738496,
#    'filehash': 'e9ba997cede7bf3514d2ba3e624ff767',
#    'modified': 1616764092.4112012},
#   {'filename': 'en_windows_7_professional_x64_dvd.iso',
#    'filemode': 33206,
#    'filesize': 3320903680,
#    'filehash': 'ed15956fe33c13642a6d2cb2c7aa9749',
#    'modified': 1604051813.6592114},
#   {'filename': 'en_windows_xp_professional_with_service_pack_3_x86_cd_vl_x14-73974.iso',
#    'filemode': 33206,
#    'filesize': 617754624,
#    'filehash': '5bf476e2fc445b8d06b3c2a6091fe3aa',
#    'modified': 1614603770.4073615},
#   {'filename': 'rufus.ini',
#    'filemode': 16895,
#    'filelist': [{'filename': 'rufus-3.13p.exe',
#      'filemode': 33279,
#      'filesize': 1156152,
#      'filehash': 'c844fa688f3aafa80790ecd6a204bbb7',
#      'modified': 1617340036.961554},
#     {'filename': 'rufus.ini',
#      'filemode': 33206,
#      'filesize': 67,
#      'filehash': '62359f051ac88408e21f2ff929fe084a',
#      'modified': 1620307484.1363404}]},
#   {'filename': 'ubuntu-10.04.4-desktop-amd64.iso',
#    'filemode': 33206,
#    'filesize': 729481216,
#    'filehash': '1c0feea62a3ab961a90dad75c6990d21',
#    'modified': 1616830649.8136954},
#   {'filename': 'ubuntu-18.04-desktop-amd64.iso',
#    'filemode': 33206,
#    'filesize': 1921843200,
#    'filehash': '129292a182136a35e1f89c586dbac2e2',
#    'modified': 1620458843.4104705},
#   {'filename': 'ubuntu-18.04.5-desktop-amd64.iso',
#    'filemode': 33206,
#    'filesize': 2193522688,
#    'filehash': '44343bc1373c6dc826ebb58839155c39',
#    'modified': 1610793638.9422164},
#   {'filename': 'ubuntu-18.04.5-preinstalled-server-armhf+raspi3.img.xz',
#    'filemode': 33206,
#    'filesize': 499504344,
#    'filehash': '6c64c3d9cc982849e0ad80d979f3dd0e',
#    'modified': 1604051700.710238},
#   {'filename': 'ubuntu-20.04.1-desktop-amd64.iso',
#    'filemode': 33206,
#    'filesize': 2785017856,
#    'filehash': '77fc715a283e41d0ad33d6418a9ba128',
#    'modified': 1603795441.2676573},
#   {'filename': 'ubuntu-20.04.1-preinstalled-server-armhf+raspi.img.xz',
#    'filemode': 33206,
#    'filesize': 676987704,
#    'filehash': 'c0b720fff36ea14d070b833d5de824b3',
#    'modified': 1604051718.3054552},
#   {'filename': 'ubuntu-20.04.2.0-desktop-amd64.iso',
#    'filemode': 33206,
#    'filesize': 2877227008,
#    'filehash': '2b0bfcb7e9e95c8eadb14a6fb59efae8',
#    'modified': 1612897632.0},
#   {'filename': 'Win10_21H1_EnglishInternational_x64.iso',
#    'filemode': 33206,
#    'filesize': 5832765440,
#    'filehash': 'b51e1111832c42b5917947d8ca1d611b',
#    'modified': 1625921114.670044},
#   {'filename': 'Win10_21H1_English_x32.iso',
#    'filemode': 33206,
#    'filesize': 4143611904,
#    'filehash': '6cce28f3b9381810c9e7134eeda506b2',
#    'modified': 1625935993.8350923},
#   {'filename': 'Win10_21H1_English_x64.iso',
#    'filemode': 33206,
#    'filesize': 5824122880,
#    'filehash': '55ca8af002fa2f8bc14cb2aaf7743400',
#    'modified': 1625935979.946597},
#   {'filename': 'Win10_21H1_Japanese_x64.iso',
#    'filemode': 33206,
#    'filesize': 5731651584,
#    'filehash': '7c7d4c7b0aa8848a379c4b770a021478',
#    'modified': 1625925490.387623},
#   {'filename': 'win7sp1_ldr_escrow_CLIENT_PROFESSIONAL_x64FRE_en-us.iso',
#    'filemode': 33206,
#    'filesize': 5898725376,
#    'filehash': '262ff7318b375bdb70fdf84a3f6c3384',
#    'modified': 1604051970.5628946},
#   {'filename': 'Windows-20210320.iso',
#    'filemode': 33206,
#    'filesize': 4899078144,
#    'filehash': 'e5258b15095d96f79bdc38f812183842',
#    'modified': 1616233966.9766722},
#   {'filename': 'Windows.iso',
#    'filemode': 33206,
#    'filesize': 4899078144,
#    'filehash': '6c7b190876b7c0777721c922de0b14ae',
#    'modified': 1620923310.3705027},
#   {'filename': 'windows_xp_sp2_w2k3sp2_3959_usa_x64fre_spcd.iso',
#    'filemode': 33206,
#    'filesize': 498071552,
#    'filehash': '645a05b8ffa50c8327011978c5faf710',
#    'modified': 1605367777.3906612},
#   {'filename': 'ja_windows_xp_professional_with_service_pack_3_x86_dvd_vl_x14-74058_key.txt',
#    'filemode': 16895,
#    'filelist': [{'filename': 'en_windows_xp_professional_with_service_pack_3_x86_cd_vl_x14-73974.iso',
#      'filemode': 33206,
#      'filesize': 617754624,
#      'filehash': '5bf476e2fc445b8d06b3c2a6091fe3aa',
#      'modified': 1614603770.4073615},
#     {'filename': 'ja_windows_xp_professional_with_service_pack_3_x86_dvd_vl_x14-74058.iso',
#      'filemode': 33206,
#      'filesize': 660817920,
#      'filehash': '32c71fa56a09c4a7f6e315e31933d6a3',
#      'modified': 1331711075.2061324},
#     {'filename': 'ja_windows_xp_professional_with_service_pack_3_x86_dvd_vl_x14-74058_key.txt',
#      'filemode': 33206,
#      'filesize': 30,
#      'filehash': '9f8c77e0321e0ed86eb26d2f5942eaf7',
#      'modified': 1614605092.184}]}]}
